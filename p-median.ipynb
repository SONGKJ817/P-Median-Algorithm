# %% [markdown]
# # p-median

# %% [markdown]
# ## 필요한 모듈 설치 및 라이브러리 불러오기

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install pulp
# !pip install haversine
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Collecting haversine
#   Downloading haversine-2.8.0-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.0

# %%
# data handling
import pandas as pd
import numpy as np
import random
import warnings
warnings.filterwarnings(action = "ignore")

# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# 좌표 단위 변환
from functools import partial
from pyproj import Proj, transform

# p-median
from pulp import *

# %%
shelter = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P-Median-Algorithm/data/수해대피소.csv")
people = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P-Median-Algorithm/data/기초생활수급자_독산1동.csv")

# %%
people_lat = people['Y']
people_long = people['X']

shelter_lat = shelter['Y']
shelter_long = shelter['X']

# %%
from haversine import haversine

# %% [markdown]
# - 가중치 아이디어(1 ~ 1.5) -> 비슷한 거리에 있을 때 더 수용 가능한 곳으로 가도록 하게 하기 위해
#   - shelter['weight'][j] : j번째 시설의 해당 weight (학교가 가장 대피하기 좋은 장소(수용인원이 많음) 기준 1로 두고 나머지 유형의 대피소의 가중치는 학교 수용인원수 / 해당 유형의 대피소의 수용인원수)
#   - minmaxscaling 후 2로 나누고 1을 더하기

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()
shelter["weight"] = mm.fit_transform(shelter[["weight"]])

for j in range(shelter.shape[0]):
    shelter["weight"][j] = shelter["weight"][j]/2 + 1

c = []
for i in range(people.shape[0]):
    list_ = []
    for j in range(shelter.shape[0]):
        start = (float(people_lat[i]), float(people_long[i]))
        goal = (float(shelter_lat[j]), float(shelter_long[j]))
        list_.append(haversine(start, goal) * (shelter["weight"][j]))
    c.append(list_)

# %% [markdown]
# - c : 각 시설별로 각 고객에게 서비스를 제공하는 비용(cost함수 정의 후 만들기)
# - i행은 고객을 나타냄
# - j열은 시설을 나타냄
# - c[i][j] : i번째 고객에게 j번째 facility가 서비스를 제공하는 비용

# %% [markdown]
# - m : 고객의 수(기초수급자의 수 : 1306)
# - n : 시설의 수(공공기관의 수 : 111)
# - p : 찾을 시설의 수(면적으로 나누기)

# %%
m = 1306
n = 111
p = 6

# 문제 정의
prob = LpProblem("p-median", LpMinimize)

# 결정 변수 정의
x = LpVariable.dicts("x", [(i,j) for i in range(m) for j in range(n)], 0, 1, LpBinary)
y = LpVariable.dicts("y", [j for j in range(n)], 0, 1, LpBinary)

# %% [markdown]
# - x는 이진 결정 변수의 dictionary를 정의
#     - 각 변수는 i고객이 j시설에 할당되었는지 여부를 나타냄
#
# - 각각의 시설이 열렸는지 닫혔는지?

# %%
# 목적함수 정의
prob += lpSum([c[i][j] * x[(i,j)] for i in range(m) for j in range(n)])

# %%
for i in range(m):
    prob += lpSum([x[(i,j)] for j in range(n)]) == 1
# 한 사람은(i번째 사람) 한 시설(j번째 시설)에만 영향을 받아야 함

for i in range(m):
    for j in range(n):
        prob += x[(i,j)] <= y[j]
# 시설이 열려 있어야지 영향을 받고 있는지 여부를 0과 1로 결정할 수 있음

prob += lpSum([y[j] for j in range(n)]) == p
# 시설이 열려있는 수는 우리가 원하는 시설의 수와 같아야됨

# %%
# branch-and-bound algorithm을 이용해 문제 해결하기
random.seed(123)
prob.solve(PULP_CBC_CMD(gapRel=0.0, threads=1, timeLimit=120))
# Out:
# 1

# %% [markdown]
# - gapRel = 0.0 : 주어진 시간 제한 내에서 최상의 솔루션을 찾을 때까지 최적의 솔루션을 계속 검색
# - threads = 1 : 병렬 컴퓨팅에 사용할 수 있는 thread 수를 의미, 단일 thread 모들에서 실행한다는 의미인 1로 실행
# - timeLimit = 600 : 솔루션을 찾는 데 사용할 수 있는 최대 시간(초)

# %%
# Print results
print("Optimal objective value:", value(prob.objective))
for j in range(n):
    if y[j].value() > 0.5:
        print("Facility", j, "is located.")
        for i in range(m):
                if x[(i,j)].value() > 0.5:
                    print("- Customer", i, "is served.")
# Out:
# Optimal objective value: 344.09722953252765
# Facility 14 is located.
# - Customer 4 is served.
# - Customer 9 is served.
# - Customer 19 is served.
# - Customer 23 is served.
# - Customer 26 is served.
# - Customer 31 is served.
# - Customer 87 is served.
# - Customer 89 is served.
# - Customer 92 is served.
# - Customer 99 is served.
# - Customer 100 is served.
# - Customer 125 is served.
# - Customer 130 is served.
# - Customer 135 is served.
# - Customer 148 is served.
# - Customer 152 is served.
# - Customer 155 is served.
# - Customer 163 is served.
# - Customer 172 is served.
# - Customer 173 is served.
# - Customer 176 is served.
# - Customer 177 is served.
# - Customer 178 is served.
# - Customer 179 is served.
# - Customer 189 is served.
# - Customer 236 is served.
# - Customer 264 is served.
# - Customer 271 is served.
# - Customer 273 is served.
# - Customer 290 is served.
# - Customer 301 is served.
# - Customer 307 is served.
# - Customer 312 is served.
# - Customer 313 is served.
# - Customer 315 is served.
# - Customer 319 is served.
# - Customer 325 is served.
# - Customer 349 is served.
# - Customer 357 is served.
# - Customer 371 is served.
# - Customer 375 is served.
# - Customer 398 is served.
# - Customer 403 is served.
# - Customer 424 is served.
# - Customer 425 is served.
# - Customer 444 is served.
# - Customer 446 is served.
# - Customer 483 is served.
# - Customer 503 is served.
# - Customer 505 is served.
# - Customer 511 is served.
# - Customer 525 is served.
# - Customer 528 is served.
# - Customer 541 is served.
# - Customer 547 is served.
# - Customer 571 is served.
# - Customer 572 is served.
# - Customer 577 is served.
# - Customer 579 is served.
# - Customer 588 is served.
# - Customer 600 is served.
# - Customer 610 is served.
# - Customer 621 is served.
# - Customer 638 is served.
# - Customer 639 is served.
# - Customer 646 is served.
# - Customer 652 is served.
# - Customer 654 is served.
# - Customer 660 is served.
# - Customer 671 is served.
# - Customer 683 is served.
# - Customer 706 is served.
# - Customer 707 is served.
# - Customer 709 is served.
# - Customer 715 is served.
# - Customer 724 is served.
# - Customer 729 is served.
# - Customer 731 is served.
# - Customer 732 is served.
# - Customer 735 is served.
# - Customer 746 is served.
# - Customer 747 is served.
# - Customer 756 is served.
# - Customer 759 is served.
# - Customer 765 is served.
# - Customer 773 is served.
# - Customer 783 is served.
# - Customer 786 is served.
# - Customer 789 is served.
# - Customer 791 is served.
# - Customer 799 is served.
# - Customer 804 is served.
# - Customer 808 is served.
# - Customer 816 is served.
# - Customer 820 is served.
# - Customer 821 is served.
# - Customer 843 is served.
# - Customer 844 is served.
# - Customer 867 is served.
# - Customer 869 is served.
# - Customer 874 is served.
# - Customer 883 is served.
# - Customer 885 is served.
# - Customer 895 is served.
# - Customer 901 is served.
# - Customer 910 is served.
# - Customer 915 is served.
# - Customer 918 is served.
# - Customer 928 is served.
# - Customer 929 is served.
# - Customer 939 is served.
# - Customer 947 is served.
# - Customer 961 is served.
# - Customer 963 is served.
# - Customer 987 is served.
# - Customer 991 is served.
# - Customer 993 is served.
# - Customer 996 is served.
# - Customer 1003 is served.
# - Customer 1006 is served.
# - Customer 1033 is served.
# - Customer 1035 is served.
# - Customer 1058 is served.
# - Customer 1060 is served.
# - Customer 1090 is served.
# - Customer 1093 is served.
# - Customer 1095 is served.
# - Customer 1099 is served.
# - Customer 1123 is served.
# - Customer 1126 is served.
# - Customer 1128 is served.
# - Customer 1129 is served.
# - Customer 1137 is served.
# - Customer 1140 is served.
# - Customer 1154 is served.
# - Customer 1156 is served.
# - Customer 1164 is served.
# - Customer 1171 is served.
# - Customer 1173 is served.
# - Customer 1174 is served.
# - Customer 1217 is served.
# - Customer 1218 is served.
# - Customer 1229 is served.
# - Customer 1231 is served.
# - Customer 1237 is served.
# - Customer 1240 is served.
# - Customer 1256 is served.
# - Customer 1265 is served.
# - Customer 1282 is served.
# - Customer 1285 is served.
# Facility 19 is located.
# - Customer 1 is served.
# - Customer 3 is served.
# - Customer 7 is served.
# - Customer 8 is served.
# - Customer 15 is served.
# - Customer 21 is served.
# - Customer 22 is served.
# - Customer 27 is served.
# - Customer 28 is served.
# - Customer 29 is served.
# - Customer 30 is served.
# - Customer 39 is served.
# - Customer 44 is served.
# - Customer 45 is served.
# - Customer 47 is served.
# - Customer 50 is served.
# - Customer 54 is served.
# - Customer 55 is served.
# - Customer 57 is served.
# - Customer 69 is served.
# - Customer 80 is served.
# - Customer 94 is served.
# - Customer 101 is served.
# - Customer 103 is served.
# - Customer 107 is served.
# - Customer 108 is served.
# - Customer 114 is served.
# - Customer 118 is served.
# - Customer 120 is served.
# - Customer 126 is served.
# - Customer 131 is served.
# - Customer 132 is served.
# - Customer 133 is served.
# - Customer 141 is served.
# - Customer 150 is served.
# - Customer 151 is served.
# - Customer 158 is served.
# - Customer 160 is served.
# - Customer 167 is served.
# - Customer 171 is served.
# - Customer 174 is served.
# - Customer 185 is served.
# - Customer 187 is served.
# - Customer 194 is served.
# - Customer 196 is served.
# - Customer 201 is served.
# - Customer 206 is served.
# - Customer 208 is served.
# - Customer 212 is served.
# - Customer 216 is served.
# - Customer 222 is served.
# - Customer 228 is served.
# - Customer 230 is served.
# - Customer 233 is served.
# - Customer 240 is served.
# - Customer 245 is served.
# - Customer 254 is served.
# - Customer 256 is served.
# - Customer 258 is served.
# - Customer 263 is served.
# - Customer 275 is served.
# - Customer 280 is served.
# - Customer 292 is served.
# - Customer 300 is served.
# - Customer 326 is served.
# - Customer 328 is served.
# - Customer 334 is served.
# - Customer 335 is served.
# - Customer 338 is served.
# - Customer 339 is served.
# - Customer 344 is served.
# - Customer 345 is served.
# - Customer 347 is served.
# - Customer 351 is served.
# - Customer 363 is served.
# - Customer 365 is served.
# - Customer 367 is served.
# - Customer 377 is served.
# - Customer 379 is served.
# - Customer 380 is served.
# - Customer 385 is served.
# - Customer 387 is served.
# - Customer 388 is served.
# - Customer 392 is served.
# - Customer 395 is served.
# - Customer 399 is served.
# - Customer 407 is served.
# - Customer 408 is served.
# - Customer 409 is served.
# - Customer 416 is served.
# - Customer 421 is served.
# - Customer 439 is served.
# - Customer 441 is served.
# - Customer 447 is served.
# - Customer 450 is served.
# - Customer 451 is served.
# - Customer 452 is served.
# - Customer 455 is served.
# - Customer 458 is served.
# - Customer 460 is served.
# - Customer 467 is served.
# - Customer 484 is served.
# - Customer 485 is served.
# - Customer 489 is served.
# - Customer 494 is served.
# - Customer 516 is served.
# - Customer 521 is served.
# - Customer 526 is served.
# - Customer 532 is served.
# - Customer 533 is served.
# - Customer 536 is served.
# - Customer 538 is served.
# - Customer 539 is served.
# - Customer 550 is served.
# - Customer 556 is served.
# - Customer 563 is served.
# - Customer 565 is served.
# - Customer 566 is served.
# - Customer 569 is served.
# - Customer 570 is served.
# - Customer 576 is served.
# - Customer 578 is served.
# - Customer 582 is served.
# - Customer 583 is served.
# - Customer 587 is served.
# - Customer 591 is served.
# - Customer 603 is served.
# - Customer 605 is served.
# - Customer 608 is served.
# - Customer 611 is served.
# - Customer 615 is served.
# - Customer 620 is served.
# - Customer 623 is served.
# - Customer 626 is served.
# - Customer 630 is served.
# - Customer 632 is served.
# - Customer 643 is served.
# - Customer 649 is served.
# - Customer 651 is served.
# - Customer 656 is served.
# - Customer 657 is served.
# - Customer 661 is served.
# - Customer 669 is served.
# - Customer 681 is served.
# - Customer 686 is served.
# - Customer 687 is served.
# - Customer 689 is served.
# - Customer 691 is served.
# - Customer 692 is served.
# - Customer 693 is served.
# - Customer 696 is served.
# - Customer 710 is served.
# - Customer 713 is served.
# - Customer 720 is served.
# - Customer 749 is served.
# - Customer 754 is served.
# - Customer 764 is served.
# - Customer 774 is served.
# - Customer 775 is served.
# - Customer 793 is served.
# - Customer 797 is served.
# - Customer 803 is served.
# - Customer 806 is served.
# - Customer 811 is served.
# - Customer 815 is served.
# - Customer 819 is served.
# - Customer 832 is served.
# - Customer 836 is served.
# - Customer 838 is served.
# - Customer 849 is served.
# - Customer 856 is served.
# - Customer 860 is served.
# - Customer 863 is served.
# - Customer 868 is served.
# - Customer 873 is served.
# - Customer 882 is served.
# - Customer 887 is served.
# - Customer 890 is served.
# - Customer 898 is served.
# - Customer 903 is served.
# - Customer 907 is served.
# - Customer 908 is served.
# - Customer 909 is served.
# - Customer 914 is served.
# - Customer 932 is served.
# - Customer 937 is served.
# - Customer 949 is served.
# - Customer 955 is served.
# - Customer 962 is served.
# - Customer 971 is served.
# - Customer 975 is served.
# - Customer 978 is served.
# - Customer 979 is served.
# - Customer 988 is served.
# - Customer 994 is served.
# - Customer 1009 is served.
# - Customer 1012 is served.
# - Customer 1014 is served.
# - Customer 1018 is served.
# - Customer 1020 is served.
# - Customer 1022 is served.
# - Customer 1025 is served.
# - Customer 1026 is served.
# - Customer 1034 is served.
# - Customer 1038 is served.
# - Customer 1040 is served.
# - Customer 1048 is served.
# - Customer 1053 is served.
# - Customer 1061 is served.
# - Customer 1063 is served.
# - Customer 1065 is served.
# - Customer 1066 is served.
# - Customer 1076 is served.
# - Customer 1083 is served.
# - Customer 1086 is served.
# - Customer 1101 is served.
# - Customer 1102 is served.
# - Customer 1108 is served.
# - Customer 1112 is served.
# - Customer 1113 is served.
# - Customer 1115 is served.
# - Customer 1124 is served.
# - Customer 1142 is served.
# - Customer 1145 is served.
# - Customer 1149 is served.
# - Customer 1158 is served.
# - Customer 1166 is served.
# - Customer 1169 is served.
# - Customer 1175 is served.
# - Customer 1176 is served.
# - Customer 1178 is served.
# - Customer 1180 is served.
# - Customer 1187 is served.
# - Customer 1190 is served.
# - Customer 1195 is served.
# - Customer 1205 is served.
# - Customer 1209 is served.
# - Customer 1239 is served.
# - Customer 1241 is served.
# - Customer 1243 is served.
# - Customer 1253 is served.
# - Customer 1254 is served.
# - Customer 1263 is served.
# - Customer 1267 is served.
# - Customer 1275 is served.
# - Customer 1280 is served.
# - Customer 1284 is served.
# - Customer 1292 is served.
# - Customer 1294 is served.
# - Customer 1296 is served.
# - Customer 1298 is served.
# - Customer 1301 is served.
# - Customer 1302 is served.
# - Customer 1305 is served.
# Facility 23 is located.
# - Customer 2 is served.
# - Customer 11 is served.
# - Customer 14 is served.
# - Customer 24 is served.
# - Customer 25 is served.
# - Customer 48 is served.
# - Customer 52 is served.
# - Customer 60 is served.
# - Customer 62 is served.
# - Customer 63 is served.
# - Customer 64 is served.
# - Customer 70 is served.
# - Customer 72 is served.
# - Customer 74 is served.
# - Customer 77 is served.
# - Customer 90 is served.
# - Customer 98 is served.
# - Customer 105 is served.
# - Customer 106 is served.
# - Customer 116 is served.
# - Customer 123 is served.
# - Customer 124 is served.
# - Customer 129 is served.
# - Customer 161 is served.
# - Customer 164 is served.
# - Customer 186 is served.
# - Customer 190 is served.
# - Customer 191 is served.
# - Customer 193 is served.
# - Customer 199 is served.
# - Customer 200 is served.
# - Customer 203 is served.
# - Customer 204 is served.
# - Customer 205 is served.
# - Customer 211 is served.
# - Customer 223 is served.
# - Customer 229 is served.
# - Customer 246 is served.
# - Customer 251 is served.
# - Customer 255 is served.
# - Customer 257 is served.
# - Customer 259 is served.
# - Customer 261 is served.
# - Customer 262 is served.
# - Customer 265 is served.
# - Customer 268 is served.
# - Customer 269 is served.
# - Customer 279 is served.
# - Customer 284 is served.
# - Customer 287 is served.
# - Customer 291 is served.
# - Customer 294 is served.
# - Customer 297 is served.
# - Customer 304 is served.
# - Customer 306 is served.
# - Customer 309 is served.
# - Customer 311 is served.
# - Customer 314 is served.
# - Customer 321 is served.
# - Customer 327 is served.
# - Customer 336 is served.
# - Customer 337 is served.
# - Customer 353 is served.
# - Customer 358 is served.
# - Customer 361 is served.
# - Customer 368 is served.
# - Customer 369 is served.
# - Customer 372 is served.
# - Customer 374 is served.
# - Customer 376 is served.
# - Customer 384 is served.
# - Customer 386 is served.
# - Customer 393 is served.
# - Customer 394 is served.
# - Customer 404 is served.
# - Customer 423 is served.
# - Customer 426 is served.
# - Customer 428 is served.
# - Customer 430 is served.
# - Customer 434 is served.
# - Customer 438 is served.
# - Customer 448 is served.
# - Customer 453 is served.
# - Customer 454 is served.
# - Customer 463 is served.
# - Customer 465 is served.
# - Customer 471 is served.
# - Customer 472 is served.
# - Customer 475 is served.
# - Customer 478 is served.
# - Customer 481 is served.
# - Customer 482 is served.
# - Customer 486 is served.
# - Customer 499 is served.
# - Customer 500 is served.
# - Customer 501 is served.
# - Customer 510 is served.
# - Customer 512 is served.
# - Customer 513 is served.
# - Customer 514 is served.
# - Customer 520 is served.
# - Customer 529 is served.
# - Customer 535 is served.
# - Customer 553 is served.
# - Customer 557 is served.
# - Customer 573 is served.
# - Customer 580 is served.
# - Customer 584 is served.
# - Customer 585 is served.
# - Customer 597 is served.
# - Customer 598 is served.
# - Customer 604 is served.
# - Customer 606 is served.
# - Customer 612 is served.
# - Customer 635 is served.
# - Customer 644 is served.
# - Customer 648 is served.
# - Customer 653 is served.
# - Customer 658 is served.
# - Customer 663 is served.
# - Customer 667 is served.
# - Customer 668 is served.
# - Customer 680 is served.
# - Customer 682 is served.
# - Customer 685 is served.
# - Customer 688 is served.
# - Customer 701 is served.
# - Customer 702 is served.
# - Customer 708 is served.
# - Customer 712 is served.
# - Customer 716 is served.
# - Customer 725 is served.
# - Customer 726 is served.
# - Customer 736 is served.
# - Customer 737 is served.
# - Customer 740 is served.
# - Customer 742 is served.
# - Customer 750 is served.
# - Customer 751 is served.
# - Customer 767 is served.
# - Customer 768 is served.
# - Customer 772 is served.
# - Customer 780 is served.
# - Customer 785 is served.
# - Customer 787 is served.
# - Customer 790 is served.
# - Customer 792 is served.
# - Customer 800 is served.
# - Customer 805 is served.
# - Customer 807 is served.
# - Customer 809 is served.
# - Customer 814 is served.
# - Customer 823 is served.
# - Customer 826 is served.
# - Customer 830 is served.
# - Customer 831 is served.
# - Customer 834 is served.
# - Customer 847 is served.
# - Customer 851 is served.
# - Customer 857 is served.
# - Customer 861 is served.
# - Customer 862 is served.
# - Customer 866 is served.
# - Customer 872 is served.
# - Customer 875 is served.
# - Customer 877 is served.
# - Customer 880 is served.
# - Customer 884 is served.
# - Customer 886 is served.
# - Customer 889 is served.
# - Customer 892 is served.
# - Customer 902 is served.
# - Customer 911 is served.
# - Customer 912 is served.
# - Customer 920 is served.
# - Customer 923 is served.
# - Customer 930 is served.
# - Customer 942 is served.
# - Customer 943 is served.
# - Customer 944 is served.
# - Customer 948 is served.
# - Customer 950 is served.
# - Customer 956 is served.
# - Customer 958 is served.
# - Customer 969 is served.
# - Customer 970 is served.
# - Customer 973 is served.
# - Customer 976 is served.
# - Customer 977 is served.
# - Customer 982 is served.
# - Customer 984 is served.
# - Customer 990 is served.
# - Customer 995 is served.
# - Customer 999 is served.
# - Customer 1007 is served.
# - Customer 1017 is served.
# - Customer 1019 is served.
# - Customer 1021 is served.
# - Customer 1024 is served.
# - Customer 1029 is served.
# - Customer 1043 is served.
# - Customer 1044 is served.
# - Customer 1047 is served.
# - Customer 1056 is served.
# - Customer 1059 is served.
# - Customer 1064 is served.
# - Customer 1070 is served.
# - Customer 1073 is served.
# - Customer 1074 is served.
# - Customer 1077 is served.
# - Customer 1092 is served.
# - Customer 1105 is served.
# - Customer 1106 is served.
# - Customer 1110 is served.
# - Customer 1116 is served.
# - Customer 1118 is served.
# - Customer 1125 is served.
# - Customer 1131 is served.
# - Customer 1132 is served.
# - Customer 1134 is served.
# - Customer 1144 is served.
# - Customer 1146 is served.
# - Customer 1150 is served.
# - Customer 1152 is served.
# - Customer 1153 is served.
# - Customer 1163 is served.
# - Customer 1165 is served.
# - Customer 1182 is served.
# - Customer 1186 is served.
# - Customer 1188 is served.
# - Customer 1196 is served.
# - Customer 1202 is served.
# - Customer 1204 is served.
# - Customer 1210 is served.
# - Customer 1211 is served.
# - Customer 1215 is served.
# - Customer 1221 is served.
# - Customer 1227 is served.
# - Customer 1228 is served.
# - Customer 1244 is served.
# - Customer 1248 is served.
# - Customer 1252 is served.
# - Customer 1255 is served.
# - Customer 1270 is served.
# - Customer 1271 is served.
# - Customer 1279 is served.
# - Customer 1286 is served.
# - Customer 1291 is served.
# - Customer 1295 is served.
# - Customer 1297 is served.
# - Customer 1299 is served.
# Facility 30 is located.
# - Customer 5 is served.
# - Customer 6 is served.
# - Customer 10 is served.
# - Customer 18 is served.
# - Customer 20 is served.
# - Customer 33 is served.
# - Customer 36 is served.
# - Customer 38 is served.
# - Customer 41 is served.
# - Customer 49 is served.
# - Customer 58 is served.
# - Customer 66 is served.
# - Customer 73 is served.
# - Customer 76 is served.
# - Customer 81 is served.
# - Customer 84 is served.
# - Customer 85 is served.
# - Customer 86 is served.
# - Customer 88 is served.
# - Customer 95 is served.
# - Customer 102 is served.
# - Customer 104 is served.
# - Customer 109 is served.
# - Customer 110 is served.
# - Customer 111 is served.
# - Customer 112 is served.
# - Customer 127 is served.
# - Customer 134 is served.
# - Customer 139 is served.
# - Customer 142 is served.
# - Customer 144 is served.
# - Customer 147 is served.
# - Customer 149 is served.
# - Customer 156 is served.
# - Customer 166 is served.
# - Customer 170 is served.
# - Customer 175 is served.
# - Customer 184 is served.
# - Customer 188 is served.
# - Customer 198 is served.
# - Customer 217 is served.
# - Customer 218 is served.
# - Customer 220 is served.
# - Customer 221 is served.
# - Customer 224 is served.
# - Customer 226 is served.
# - Customer 227 is served.
# - Customer 231 is served.
# - Customer 235 is served.
# - Customer 237 is served.
# - Customer 239 is served.
# - Customer 242 is served.
# - Customer 247 is served.
# - Customer 253 is served.
# - Customer 266 is served.
# - Customer 272 is served.
# - Customer 276 is served.
# - Customer 278 is served.
# - Customer 282 is served.
# - Customer 283 is served.
# - Customer 288 is served.
# - Customer 296 is served.
# - Customer 298 is served.
# - Customer 299 is served.
# - Customer 308 is served.
# - Customer 316 is served.
# - Customer 317 is served.
# - Customer 318 is served.
# - Customer 320 is served.
# - Customer 323 is served.
# - Customer 329 is served.
# - Customer 331 is served.
# - Customer 333 is served.
# - Customer 340 is served.
# - Customer 342 is served.
# - Customer 343 is served.
# - Customer 359 is served.
# - Customer 364 is served.
# - Customer 370 is served.
# - Customer 373 is served.
# - Customer 382 is served.
# - Customer 383 is served.
# - Customer 390 is served.
# - Customer 391 is served.
# - Customer 397 is served.
# - Customer 405 is served.
# - Customer 406 is served.
# - Customer 410 is served.
# - Customer 412 is served.
# - Customer 415 is served.
# - Customer 417 is served.
# - Customer 420 is served.
# - Customer 422 is served.
# - Customer 429 is served.
# - Customer 432 is served.
# - Customer 433 is served.
# - Customer 436 is served.
# - Customer 440 is served.
# - Customer 442 is served.
# - Customer 456 is served.
# - Customer 457 is served.
# - Customer 459 is served.
# - Customer 461 is served.
# - Customer 466 is served.
# - Customer 470 is served.
# - Customer 476 is served.
# - Customer 488 is served.
# - Customer 490 is served.
# - Customer 491 is served.
# - Customer 492 is served.
# - Customer 493 is served.
# - Customer 495 is served.
# - Customer 504 is served.
# - Customer 506 is served.
# - Customer 509 is served.
# - Customer 522 is served.
# - Customer 527 is served.
# - Customer 540 is served.
# - Customer 543 is served.
# - Customer 545 is served.
# - Customer 546 is served.
# - Customer 548 is served.
# - Customer 549 is served.
# - Customer 554 is served.
# - Customer 559 is served.
# - Customer 564 is served.
# - Customer 568 is served.
# - Customer 575 is served.
# - Customer 589 is served.
# - Customer 592 is served.
# - Customer 601 is served.
# - Customer 602 is served.
# - Customer 609 is served.
# - Customer 613 is served.
# - Customer 614 is served.
# - Customer 617 is served.
# - Customer 619 is served.
# - Customer 624 is served.
# - Customer 627 is served.
# - Customer 629 is served.
# - Customer 634 is served.
# - Customer 636 is served.
# - Customer 645 is served.
# - Customer 664 is served.
# - Customer 684 is served.
# - Customer 694 is served.
# - Customer 695 is served.
# - Customer 697 is served.
# - Customer 698 is served.
# - Customer 700 is served.
# - Customer 703 is served.
# - Customer 704 is served.
# - Customer 714 is served.
# - Customer 717 is served.
# - Customer 718 is served.
# - Customer 721 is served.
# - Customer 722 is served.
# - Customer 723 is served.
# - Customer 728 is served.
# - Customer 733 is served.
# - Customer 745 is served.
# - Customer 748 is served.
# - Customer 752 is served.
# - Customer 757 is served.
# - Customer 763 is served.
# - Customer 769 is served.
# - Customer 770 is served.
# - Customer 778 is served.
# - Customer 795 is served.
# - Customer 813 is served.
# - Customer 827 is served.
# - Customer 833 is served.
# - Customer 837 is served.
# - Customer 839 is served.
# - Customer 840 is served.
# - Customer 841 is served.
# - Customer 842 is served.
# - Customer 848 is served.
# - Customer 852 is served.
# - Customer 865 is served.
# - Customer 881 is served.
# - Customer 888 is served.
# - Customer 891 is served.
# - Customer 896 is served.
# - Customer 905 is served.
# - Customer 906 is served.
# - Customer 913 is served.
# - Customer 919 is served.
# - Customer 921 is served.
# - Customer 924 is served.
# - Customer 926 is served.
# - Customer 927 is served.
# - Customer 934 is served.
# - Customer 935 is served.
# - Customer 936 is served.
# - Customer 941 is served.
# - Customer 945 is served.
# - Customer 957 is served.
# - Customer 959 is served.
# - Customer 960 is served.
# - Customer 966 is served.
# - Customer 967 is served.
# - Customer 968 is served.
# - Customer 972 is served.
# - Customer 974 is served.
# - Customer 981 is served.
# - Customer 985 is served.
# - Customer 986 is served.
# - Customer 989 is served.
# - Customer 992 is served.
# - Customer 997 is served.
# - Customer 1001 is served.
# - Customer 1002 is served.
# - Customer 1008 is served.
# - Customer 1030 is served.
# - Customer 1032 is served.
# - Customer 1036 is served.
# - Customer 1045 is served.
# - Customer 1052 is served.
# - Customer 1055 is served.
# - Customer 1057 is served.
# - Customer 1067 is served.
# - Customer 1068 is served.
# - Customer 1075 is served.
# - Customer 1081 is served.
# - Customer 1084 is served.
# - Customer 1088 is served.
# - Customer 1091 is served.
# - Customer 1096 is served.
# - Customer 1104 is served.
# - Customer 1109 is served.
# - Customer 1117 is served.
# - Customer 1127 is served.
# - Customer 1130 is served.
# - Customer 1133 is served.
# - Customer 1138 is served.
# - Customer 1155 is served.
# - Customer 1159 is served.
# - Customer 1160 is served.
# - Customer 1167 is served.
# - Customer 1168 is served.
# - Customer 1172 is served.
# - Customer 1179 is served.
# - Customer 1181 is served.
# - Customer 1191 is served.
# - Customer 1198 is served.
# - Customer 1199 is served.
# - Customer 1201 is served.
# - Customer 1207 is served.
# - Customer 1208 is served.
# - Customer 1216 is served.
# - Customer 1219 is served.
# - Customer 1220 is served.
# - Customer 1222 is served.
# - Customer 1223 is served.
# - Customer 1225 is served.
# - Customer 1233 is served.
# - Customer 1235 is served.
# - Customer 1242 is served.
# - Customer 1245 is served.
# - Customer 1246 is served.
# - Customer 1250 is served.
# - Customer 1251 is served.
# - Customer 1259 is served.
# - Customer 1266 is served.
# - Customer 1272 is served.
# - Customer 1274 is served.
# - Customer 1276 is served.
# - Customer 1278 is served.
# - Customer 1293 is served.
# - Customer 1300 is served.
# - Customer 1303 is served.
# - Customer 1304 is served.
# Facility 60 is located.
# - Customer 0 is served.
# - Customer 16 is served.
# - Customer 17 is served.
# - Customer 35 is served.
# - Customer 37 is served.
# - Customer 40 is served.
# - Customer 46 is served.
# - Customer 53 is served.
# - Customer 83 is served.
# - Customer 93 is served.
# - Customer 97 is served.
# - Customer 115 is served.
# - Customer 121 is served.
# - Customer 137 is served.
# - Customer 138 is served.
# - Customer 143 is served.
# - Customer 146 is served.
# - Customer 153 is served.
# - Customer 157 is served.
# - Customer 168 is served.
# - Customer 169 is served.
# - Customer 180 is served.
# - Customer 202 is served.
# - Customer 209 is served.
# - Customer 210 is served.
# - Customer 215 is served.
# - Customer 219 is served.
# - Customer 232 is served.
# - Customer 234 is served.
# - Customer 238 is served.
# - Customer 241 is served.
# - Customer 249 is served.
# - Customer 250 is served.
# - Customer 252 is served.
# - Customer 260 is served.
# - Customer 267 is served.
# - Customer 285 is served.
# - Customer 286 is served.
# - Customer 324 is served.
# - Customer 332 is served.
# - Customer 346 is served.
# - Customer 354 is served.
# - Customer 360 is served.
# - Customer 366 is served.
# - Customer 378 is served.
# - Customer 402 is served.
# - Customer 411 is served.
# - Customer 414 is served.
# - Customer 427 is served.
# - Customer 435 is served.
# - Customer 437 is served.
# - Customer 443 is served.
# - Customer 468 is served.
# - Customer 474 is served.
# - Customer 480 is served.
# - Customer 497 is served.
# - Customer 502 is served.
# - Customer 524 is served.
# - Customer 530 is served.
# - Customer 537 is served.
# - Customer 542 is served.
# - Customer 551 is served.
# - Customer 574 is served.
# - Customer 593 is served.
# - Customer 596 is served.
# - Customer 625 is served.
# - Customer 631 is served.
# - Customer 642 is served.
# - Customer 647 is served.
# - Customer 665 is served.
# - Customer 666 is served.
# - Customer 672 is served.
# - Customer 675 is served.
# - Customer 677 is served.
# - Customer 705 is served.
# - Customer 730 is served.
# - Customer 738 is served.
# - Customer 753 is served.
# - Customer 760 is served.
# - Customer 762 is served.
# - Customer 766 is served.
# - Customer 771 is served.
# - Customer 776 is served.
# - Customer 777 is served.
# - Customer 779 is served.
# - Customer 788 is served.
# - Customer 798 is served.
# - Customer 801 is served.
# - Customer 812 is served.
# - Customer 817 is served.
# - Customer 818 is served.
# - Customer 822 is served.
# - Customer 824 is served.
# - Customer 825 is served.
# - Customer 845 is served.
# - Customer 855 is served.
# - Customer 859 is served.
# - Customer 864 is served.
# - Customer 871 is served.
# - Customer 916 is served.
# - Customer 931 is served.
# - Customer 953 is served.
# - Customer 983 is served.
# - Customer 1004 is served.
# - Customer 1013 is served.
# - Customer 1023 is served.
# - Customer 1028 is served.
# - Customer 1037 is served.
# - Customer 1039 is served.
# - Customer 1041 is served.
# - Customer 1046 is served.
# - Customer 1050 is served.
# - Customer 1051 is served.
# - Customer 1054 is served.
# - Customer 1072 is served.
# - Customer 1085 is served.
# - Customer 1087 is served.
# - Customer 1094 is served.
# - Customer 1098 is served.
# - Customer 1107 is served.
# - Customer 1114 is served.
# - Customer 1119 is served.
# - Customer 1120 is served.
# - Customer 1121 is served.
# - Customer 1122 is served.
# - Customer 1139 is served.
# - Customer 1141 is served.
# - Customer 1143 is served.
# - Customer 1147 is served.
# - Customer 1148 is served.
# - Customer 1183 is served.
# - Customer 1184 is served.
# - Customer 1193 is served.
# - Customer 1200 is served.
# - Customer 1212 is served.
# - Customer 1224 is served.
# - Customer 1230 is served.
# - Customer 1249 is served.
# - Customer 1260 is served.
# - Customer 1264 is served.
# - Customer 1281 is served.
# Facility 107 is located.
# - Customer 12 is served.
# - Customer 13 is served.
# - Customer 32 is served.
# - Customer 34 is served.
# - Customer 42 is served.
# - Customer 43 is served.
# - Customer 51 is served.
# - Customer 56 is served.
# - Customer 59 is served.
# - Customer 61 is served.
# - Customer 65 is served.
# - Customer 67 is served.
# - Customer 68 is served.
# - Customer 71 is served.
# - Customer 75 is served.
# - Customer 78 is served.
# - Customer 79 is served.
# - Customer 82 is served.
# - Customer 91 is served.
# - Customer 96 is served.
# - Customer 113 is served.
# - Customer 117 is served.
# - Customer 119 is served.
# - Customer 122 is served.
# - Customer 128 is served.
# - Customer 136 is served.
# - Customer 140 is served.
# - Customer 145 is served.
# - Customer 154 is served.
# - Customer 159 is served.
# - Customer 162 is served.
# - Customer 165 is served.
# - Customer 181 is served.
# - Customer 182 is served.
# - Customer 183 is served.
# - Customer 192 is served.
# - Customer 195 is served.
# - Customer 197 is served.
# - Customer 207 is served.
# - Customer 213 is served.
# - Customer 214 is served.
# - Customer 225 is served.
# - Customer 243 is served.
# - Customer 244 is served.
# - Customer 248 is served.
# - Customer 270 is served.
# - Customer 274 is served.
# - Customer 277 is served.
# - Customer 281 is served.
# - Customer 289 is served.
# - Customer 293 is served.
# - Customer 295 is served.
# - Customer 302 is served.
# - Customer 303 is served.
# - Customer 305 is served.
# - Customer 310 is served.
# - Customer 322 is served.
# - Customer 330 is served.
# - Customer 341 is served.
# - Customer 348 is served.
# - Customer 350 is served.
# - Customer 352 is served.
# - Customer 355 is served.
# - Customer 356 is served.
# - Customer 362 is served.
# - Customer 381 is served.
# - Customer 389 is served.
# - Customer 396 is served.
# - Customer 400 is served.
# - Customer 401 is served.
# - Customer 413 is served.
# - Customer 418 is served.
# - Customer 419 is served.
# - Customer 431 is served.
# - Customer 445 is served.
# - Customer 449 is served.
# - Customer 462 is served.
# - Customer 464 is served.
# - Customer 469 is served.
# - Customer 473 is served.
# - Customer 477 is served.
# - Customer 479 is served.
# - Customer 487 is served.
# - Customer 496 is served.
# - Customer 498 is served.
# - Customer 507 is served.
# - Customer 508 is served.
# - Customer 515 is served.
# - Customer 517 is served.
# - Customer 518 is served.
# - Customer 519 is served.
# - Customer 523 is served.
# - Customer 531 is served.
# - Customer 534 is served.
# - Customer 544 is served.
# - Customer 552 is served.
# - Customer 555 is served.
# - Customer 558 is served.
# - Customer 560 is served.
# - Customer 561 is served.
# - Customer 562 is served.
# - Customer 567 is served.
# - Customer 581 is served.
# - Customer 586 is served.
# - Customer 590 is served.
# - Customer 594 is served.
# - Customer 595 is served.
# - Customer 599 is served.
# - Customer 607 is served.
# - Customer 616 is served.
# - Customer 618 is served.
# - Customer 622 is served.
# - Customer 628 is served.
# - Customer 633 is served.
# - Customer 637 is served.
# - Customer 640 is served.
# - Customer 641 is served.
# - Customer 650 is served.
# - Customer 655 is served.
# - Customer 659 is served.
# - Customer 662 is served.
# - Customer 670 is served.
# - Customer 673 is served.
# - Customer 674 is served.
# - Customer 676 is served.
# - Customer 678 is served.
# - Customer 679 is served.
# - Customer 690 is served.
# - Customer 699 is served.
# - Customer 711 is served.
# - Customer 719 is served.
# - Customer 727 is served.
# - Customer 734 is served.
# - Customer 739 is served.
# - Customer 741 is served.
# - Customer 743 is served.
# - Customer 744 is served.
# - Customer 755 is served.
# - Customer 758 is served.
# - Customer 761 is served.
# - Customer 781 is served.
# - Customer 782 is served.
# - Customer 784 is served.
# - Customer 794 is served.
# - Customer 796 is served.
# - Customer 802 is served.
# - Customer 810 is served.
# - Customer 828 is served.
# - Customer 829 is served.
# - Customer 835 is served.
# - Customer 846 is served.
# - Customer 850 is served.
# - Customer 853 is served.
# - Customer 854 is served.
# - Customer 858 is served.
# - Customer 870 is served.
# - Customer 876 is served.
# - Customer 878 is served.
# - Customer 879 is served.
# - Customer 893 is served.
# - Customer 894 is served.
# - Customer 897 is served.
# - Customer 899 is served.
# - Customer 900 is served.
# - Customer 904 is served.
# - Customer 917 is served.
# - Customer 922 is served.
# - Customer 925 is served.
# - Customer 933 is served.
# - Customer 938 is served.
# - Customer 940 is served.
# - Customer 946 is served.
# - Customer 951 is served.
# - Customer 952 is served.
# - Customer 954 is served.
# - Customer 964 is served.
# - Customer 965 is served.
# - Customer 980 is served.
# - Customer 998 is served.
# - Customer 1000 is served.
# - Customer 1005 is served.
# - Customer 1010 is served.
# - Customer 1011 is served.
# - Customer 1015 is served.
# - Customer 1016 is served.
# - Customer 1027 is served.
# - Customer 1031 is served.
# - Customer 1042 is served.
# - Customer 1049 is served.
# - Customer 1062 is served.
# - Customer 1069 is served.
# - Customer 1071 is served.
# - Customer 1078 is served.
# - Customer 1079 is served.
# - Customer 1080 is served.
# - Customer 1082 is served.
# - Customer 1089 is served.
# - Customer 1097 is served.
# - Customer 1100 is served.
# - Customer 1103 is served.
# - Customer 1111 is served.
# - Customer 1135 is served.
# - Customer 1136 is served.
# - Customer 1151 is served.
# - Customer 1157 is served.
# - Customer 1161 is served.
# - Customer 1162 is served.
# - Customer 1170 is served.
# - Customer 1177 is served.
# - Customer 1185 is served.
# - Customer 1189 is served.
# - Customer 1192 is served.
# - Customer 1194 is served.
# - Customer 1197 is served.
# - Customer 1203 is served.
# - Customer 1206 is served.
# - Customer 1213 is served.
# - Customer 1214 is served.
# - Customer 1226 is served.
# - Customer 1232 is served.
# - Customer 1234 is served.
# - Customer 1236 is served.
# - Customer 1238 is served.
# - Customer 1247 is served.
# - Customer 1257 is served.
# - Customer 1258 is served.
# - Customer 1261 is served.
# - Customer 1262 is served.
# - Customer 1268 is served.
# - Customer 1269 is served.
# - Customer 1273 is served.
# - Customer 1277 is served.
# - Customer 1283 is served.
# - Customer 1287 is served.
# - Customer 1288 is served.
# - Customer 1289 is served.
# - Customer 1290 is served.

# %% [markdown]
# - 첫 번째 줄 : p개 시설을 open했을 때 최소 비용을 인쇄(목표 값)
# - 그 다음 각각 시설에 대해 코드가 시설이 열렸는지 여부를 확인
#     - y[j]의 값이 0.5보다 크면 j번째 시설이 열렸다는 의미

# %%
import folium
lat = shelter['Y'].mean()
long = shelter['X'].mean()

#지도 띄우기
m = folium.Map([lat, long], zoom_start = 20)

#for n in range(shelter.shape[0]):
for n in (14, 19, 23, 30, 60, 107):
    #name = df_seoul_hospital.loc[n, "상호명"]
    #address = df_seoul_hospital.loc[n, "도로명주소"]
    popup = shelter.loc[n, 'shelter'],
    location = [shelter.loc[n, "Y"], shelter.loc[n, "X"]]
    folium.Marker(
        location = location,
        popup = popup
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50d289417d99f2f9460f6edf909e570e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50d289417d99f2f9460f6edf909e570e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50d289417d99f2f9460f6edf909e570e = L.map(
#                 &quot;map_50d289417d99f2f9460f6edf909e570e&quot;,
#                 {
#                     center: [37.46062267477478, 126.90220741441439],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe7156bc750c3401d5f4f621394f9e55 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_50d289417d99f2f9460f6edf909e570e);
#
#
#             var marker_c9ec4fc80c16178829f1a78521a99ae9 = L.marker(
#                 [37.4746266, 126.895601],
#                 {}
#             ).addTo(map_50d289417d99f2f9460f6edf909e570e);
#
#
#         var popup_6742a28f00f549f5454d4085b805cfa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6aab8990f11f3e533b6f358d894f358 = $(`&lt;div id=&quot;html_e6aab8990f11f3e533b6f358d894f358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;세일중학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_6742a28f00f549f5454d4085b805cfa7.setContent(html_e6aab8990f11f3e533b6f358d894f358);
#
#
#
#         marker_c9ec4fc80c16178829f1a78521a99ae9.bindPopup(popup_6742a28f00f549f5454d4085b805cfa7)
#         ;
#
#
#
#
#             var marker_7271d41f909d9ed3ec13a32bbebe3d01 = L.marker(
#                 [37.4684446, 126.894412],
#                 {}
#             ).addTo(map_50d289417d99f2f9460f6edf909e570e);
#
#
#         var popup_f3ae86d6b4b34baffeb914f49e538e95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54aee63fdaf7a57009212c367acd74fe = $(`&lt;div id=&quot;html_54aee63fdaf7a57009212c367acd74fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;가산중학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_f3ae86d6b4b34baffeb914f49e538e95.setContent(html_54aee63fdaf7a57009212c367acd74fe);
#
#
#
#         marker_7271d41f909d9ed3ec13a32bbebe3d01.bindPopup(popup_f3ae86d6b4b34baffeb914f49e538e95)
#         ;
#
#
#
#
#             var marker_905848ae73008ced5bd7bfd28ece90e1 = L.marker(
#                 [37.4581676, 126.888492],
#                 {}
#             ).addTo(map_50d289417d99f2f9460f6edf909e570e);
#
#
#         var popup_e3a11133cebb23ef40149ec6d0b9aa17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_758620bf8933b2520dddba1938140903 = $(`&lt;div id=&quot;html_758620bf8933b2520dddba1938140903&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;서울안천초등학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_e3a11133cebb23ef40149ec6d0b9aa17.setContent(html_758620bf8933b2520dddba1938140903);
#
#
#
#         marker_905848ae73008ced5bd7bfd28ece90e1.bindPopup(popup_e3a11133cebb23ef40149ec6d0b9aa17)
#         ;
#
#
#
#
#             var marker_b18aeefd1853df9a7b9ad73ee19185b6 = L.marker(
#                 [37.467144, 126.890988],
#                 {}
#             ).addTo(map_50d289417d99f2f9460f6edf909e570e);
#
#
#         var popup_bbfb148064f066c696ffb446f0b00c8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd639608200b59ce5a8140025c859db6 = $(`&lt;div id=&quot;html_bd639608200b59ce5a8140025c859db6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;서울두산초등학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_bbfb148064f066c696ffb446f0b00c8d.setContent(html_bd639608200b59ce5a8140025c859db6);
#
#
#
#         marker_b18aeefd1853df9a7b9ad73ee19185b6.bindPopup(popup_bbfb148064f066c696ffb446f0b00c8d)
#         ;
#
#
#
#
#             var marker_1ff6fda95ec99b40726a32a40dde471a = L.marker(
#                 [37.4645891, 126.895287],
#                 {}
#             ).addTo(map_50d289417d99f2f9460f6edf909e570e);
#
#
#         var popup_04367bd8f3a47f7fe46fa6fa1accf4cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e68eb6835d13a4d3ff9aad104edb2e6 = $(`&lt;div id=&quot;html_5e68eb6835d13a4d3ff9aad104edb2e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;경로당17&#x27;,)&lt;/div&gt;`)[0];
#                 popup_04367bd8f3a47f7fe46fa6fa1accf4cf.setContent(html_5e68eb6835d13a4d3ff9aad104edb2e6);
#
#
#
#         marker_1ff6fda95ec99b40726a32a40dde471a.bindPopup(popup_04367bd8f3a47f7fe46fa6fa1accf4cf)
#         ;
#
#
#
#
#             var marker_ded7da6596d1bb0cba6128fe63aadd54 =

# %%
df_result = shelter.loc[[14, 19, 23, 30, 60, 107]]
df_result
# Out:
#       shelter           X          Y  weight
# 14      세일중학교  126.895601  37.474627     1.0
# 19      가산중학교  126.894412  37.468445     1.0
# 23   서울안천초등학교  126.888492  37.458168     1.0
# 30   서울두산초등학교  126.890988  37.467144     1.0
# 60      경로당17  126.895287  37.464589     1.5
# 107     경로당64  126.892150  37.461081     1.5

# %% [markdown]
# ## 기대효과 분석
# - 기존 수해대피소에 비해 비용이 얼마나 감소하였는가?

# %%
shelter_located = pd.DataFrame({"shelter" : ["가산중학교", "가산초등학교", "시흥초등학교", "안천중학교"],
                         "X" : [126.894456, 126.896308, 126.904625, 126.887484],
                         "Y" : [37.46876, 37.4781501, 37.4553258, 37.4595092],
                          "weight" : [1, 1, 1, 1]})

# %%
from sklearn.preprocessing import MinMaxScaler

people_lat = people['Y']
people_long = people['X']

shelter11_lat = shelter['Y']
shelter11_long = shelter['X']

mm = MinMaxScaler()
shelter_located["weight"] = mm.fit_transform(shelter_located[["weight"]])

for j in range(shelter_located.shape[0]):
    shelter_located["weight"][j] = shelter_located["weight"][j]/2 + 1

c11 = []
for i in range(people.shape[0]):
    list_ = []
    for j in range(shelter_located.shape[0]):
        start = (float(people_lat[i]), float(people_long[i]))
        goal = (float(shelter11_lat[j]), float(shelter11_long[j]))
        list_.append(haversine(start, goal) * (shelter_located["weight"][j]))
    c11.append(list_)

# %%
m = 1306
n = 4
p = 4

# 문제 정의
prob_new = LpProblem("p-median", LpMinimize)

# 결정 변수 정의
x = LpVariable.dicts("x", [(i,j) for i in range(m) for j in range(n)], 0, 1, LpBinary)
y = LpVariable.dicts("y", [j for j in range(n)], 0, 1, LpBinary)

# %%
# 목적함수 정의
prob_new += lpSum([c11[i][j] * x[(i,j)] for i in range(m) for j in range(n)])

# %%
for i in range(m):
    prob_new += lpSum([x[(i,j)] for j in range(n)]) == 1
# 한 사람은(i번째 사람) 한 시설(j번째 시설)에만 영향을 받아야 함

for i in range(m):
    for j in range(n):
        prob_new += x[(i,j)] <= y[j]
# 시설이 열려 있어야지 영향을 받고 있는지 여부를 0과 1로 결정할 수 있음

prob_new += lpSum([y[j] for j in range(n)]) == p
# 시설이 열려있는 수는 우리가 원하는 시설의 수와 같아야됨

# %%
# branch-and-bound algorithm을 이용해 문제 해결하기
random.seed(123)
prob_new.solve(PULP_CBC_CMD(gapRel=0.0, threads=1, timeLimit=120))
# Out:
# 1

# %%
# Print results
print("Optimal objective value:", value(prob_new.objective))
for j in range(n):
    if y[j].value() > 0.5:
        print("Facility", j, "is located.")
#        for i in range(m):
#                if x[(i,j)].value() > 0.5:
#                    print("- Customer", i, "is served.")
# Out:
# Optimal objective value: 981.1411506510686
# Facility 0 is located.
# Facility 1 is located.
# Facility 2 is located.
# Facility 3 is located.

# %%
import folium
lat = shelter_located['Y'].mean()
long = shelter_located['X'].mean()

#지도 띄우기
m = folium.Map([lat, long], zoom_start = 20)

#for n in range(shelter.shape[0]):
for n in (0, 1, 2, 3):
    #name = df_seoul_hospital.loc[n, "상호명"]
    #address = df_seoul_hospital.loc[n, "도로명주소"]
    popup = shelter_located.loc[n, 'shelter'],
    location = [shelter_located.loc[n, "Y"], shelter_located.loc[n, "X"]]
    folium.Marker(
        location = location,
        popup = popup
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cd49bccae4a4f99d9c53be6de3fd691 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cd49bccae4a4f99d9c53be6de3fd691&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cd49bccae4a4f99d9c53be6de3fd691 = L.map(
#                 &quot;map_2cd49bccae4a4f99d9c53be6de3fd691&quot;,
#                 {
#                     center: [37.465436275, 126.89571825000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c894efa89cf79501480c8c6155f5ba19 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cd49bccae4a4f99d9c53be6de3fd691);
#
#
#             var marker_e7168216964ef7103716881ea1fc472e = L.marker(
#                 [37.46876, 126.894456],
#                 {}
#             ).addTo(map_2cd49bccae4a4f99d9c53be6de3fd691);
#
#
#         var popup_b598d3a8f075e8a6081d598b6d2bfa5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f15b46e45059b8f61bccabbf1b977757 = $(`&lt;div id=&quot;html_f15b46e45059b8f61bccabbf1b977757&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;가산중학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_b598d3a8f075e8a6081d598b6d2bfa5d.setContent(html_f15b46e45059b8f61bccabbf1b977757);
#
#
#
#         marker_e7168216964ef7103716881ea1fc472e.bindPopup(popup_b598d3a8f075e8a6081d598b6d2bfa5d)
#         ;
#
#
#
#
#             var marker_814fb624b025906921eb2c5968e51163 = L.marker(
#                 [37.4781501, 126.896308],
#                 {}
#             ).addTo(map_2cd49bccae4a4f99d9c53be6de3fd691);
#
#
#         var popup_fda3336d1e727174b9a630fc5a143480 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef380db6ad89dc36654924045435889f = $(`&lt;div id=&quot;html_ef380db6ad89dc36654924045435889f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;가산초등학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_fda3336d1e727174b9a630fc5a143480.setContent(html_ef380db6ad89dc36654924045435889f);
#
#
#
#         marker_814fb624b025906921eb2c5968e51163.bindPopup(popup_fda3336d1e727174b9a630fc5a143480)
#         ;
#
#
#
#
#             var marker_1fe4f7d11fa03013a3483850e8452e61 = L.marker(
#                 [37.4553258, 126.904625],
#                 {}
#             ).addTo(map_2cd49bccae4a4f99d9c53be6de3fd691);
#
#
#         var popup_0a9f271fbbba08a076c5a137d1baf98f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40a7194c03eb904b88418a30abcf7b0c = $(`&lt;div id=&quot;html_40a7194c03eb904b88418a30abcf7b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;시흥초등학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_0a9f271fbbba08a076c5a137d1baf98f.setContent(html_40a7194c03eb904b88418a30abcf7b0c);
#
#
#
#         marker_1fe4f7d11fa03013a3483850e8452e61.bindPopup(popup_0a9f271fbbba08a076c5a137d1baf98f)
#         ;
#
#
#
#
#             var marker_f75de07041367be75b93ef4d8f93554d = L.marker(
#                 [37.4595092, 126.887484],
#                 {}
#             ).addTo(map_2cd49bccae4a4f99d9c53be6de3fd691);
#
#
#         var popup_8177d4144f5eb332e05206737a6b4330 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b85f344c38db5679b44dd1cd92e4b14 = $(`&lt;div id=&quot;html_6b85f344c38db5679b44dd1cd92e4b14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;안천중학교&#x27;,)&lt;/div&gt;`)[0];
#                 popup_8177d4144f5eb332e05206737a6b4330.setContent(html_6b85f344c38db5679b44dd1cd92e4b14);
#
#
#
#         marker_f75de07041367be75b93ef4d8f93554d.bindPopup(popup_8177d4144f5eb332e05206737a6b4330)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
shelter_located
# Out:
#   shelter           X          Y  weight
# 0   가산중학교  126.894456  37.468760     1.0
# 1  가산초등학교  126.896308  37.478150     1.0
# 2  시흥초등학교  126.904625  37.455326     1.0
# 3   안천중학교  126.887484  37.459509     1.0
